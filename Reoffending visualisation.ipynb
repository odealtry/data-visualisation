# %%
import pandas as pd

# %%
data = pd.read_csv('reoffending-stats.csv', error_bad_lines=False)
data
# Out:
# b'Skipping line 209: expected 9 fields, saw 13\nSkipping line 210: expected 9 fields, saw 13\nSkipping line 212: expected 9 fields, saw 13\nSkipping line 215: expected 9 fields, saw 13\nSkipping line 216: expected 9 fields, saw 13\nSkipping line 218: expected 9 fields, saw 13\nSkipping line 219: expected 9 fields, saw 13\nSkipping line 220: expected 9 fields, saw 13\nSkipping line 222: expected 9 fields, saw 13\nSkipping line 223: expected 9 fields, saw 13\nSkipping line 224: expected 9 fields, saw 13\nSkipping line 225: expected 9 fields, saw 13\nSkipping line 226: expected 9 fields, saw 13\nSkipping line 227: expected 9 fields, saw 13\nSkipping line 228: expected 9 fields, saw 13\nSkipping line 229: expected 9 fields, saw 13\nSkipping line 230: expected 9 fields, saw 13\nSkipping line 232: expected 9 fields, saw 13\nSkipping line 233: expected 9 fields, saw 13\nSkipping line 234: expected 9 fields, saw 13\nSkipping line 235: expected 9 fields, saw 13\nSkipping line 236: expected 9 
# ...
